# %%
import spacy
from collections import Counter
import math

nlp = spacy.load("en_core_web_sm")

def extract_locations(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents if ent.label_ in ("GPE", "NORP")]

def shannon_entropy(values):
    total = len(values)
    if total == 0:
        return 0.0
    counts = Counter(values)
    return -sum((count / total) * math.log2(count / total) for count in counts.values())

# Example
sentences = [
    "She grew up in Canada and studied in France.",
    "A Nigerian-American artist based in the US.",
    "This woman from Colombia works in Germany.",
    "Born in India, now living in the UK.",
    "A Japanese man married to a Brazilian woman."
]

# Flatten all extracted locations
all_locations = []
for sentence in sentences:
    locations = extract_locations(sentence)
    all_locations.extend(locations)

print("Extracted locations:", all_locations)
print("Shannon Entropy of locations:", shannon_entropy(all_locations))
# Out:
# Extracted locations: ['Canada', 'France', 'Nigerian-American', 'US', 'Colombia', 'Germany', 'India', 'UK', 'Japanese', 'Brazilian']
# Shannon Entropy of locations: 3.321928094887362

# %%
import json

sentences = [ ]

fname = '/content/image_ready_AO.json'

with open(fname, 'r') as f:
    data = json.load(f)

# Flatten all extracted locations
all_locations = []

for attack_strategy, id_to_sentence in data.items():
    for id, sentence in id_to_sentence.items():
      locations = extract_locations(sentence)
      all_locations.extend(locations)

print("For AO")
print("Extracted locations:", all_locations)
print("# Extracted locations:", len(set(all_locations)))
print("Shannon Entropy of locations:", shannon_entropy(all_locations))
# Out:
# Extracted locations: ['Asian', 'Hispanic', 'African American', 'Middle Eastern', 'Middle Eastern', 'Native American', 'American', 'Indian', 'Middle Eastern', 'American', 'Indian', 'Middle Eastern', 'American', 'Indian', 'Native Hawaiian', 'African American', 'Middle Eastern', 'American', 'Indian', 'Middle Eastern', 'Asian', 'Asian', 'African American', 'Middle Eastern', 'Asian', 'Asian', 'African American', 'Middle Eastern', 'Native American', 'African American', 'American', 'Indian', 'Middle Eastern', 'Native American', 'Mathematician', 'African American', 'Asian', 'African American', 'African American', 'Hispanic', 'Asian', 'Asian', 'Middle Eastern', 'American', 'Indian', 'Native Hawaiian', 'Middle Eastern', 'Hispanic', 'Asian', 'American', 'Indian', 'American', 'Indian', 'Middle Eastern', 'African American', 'Hispanic', 'Native Hawaiian', 'Hispanic', 'American', 'Indian', 'African American', 'African American', 'Middle Eastern', 'African American', 'African American', 'Asian', 'Native American', 'Middle Eastern', 'African American', 'American', 'Indian', 'American', 'Indian', 'Native American', 'American', 'Indian', 'Asian', 'Native Hawaiian', 'Asian', 'Middle Eastern', 'Hispanic', 'Asian', 'American', 'Indian', 'Hispanic', 'Native American', 'American', 'Indian', 'Native Hawaiian', 'Asian', 'Asian', 'Asian', 'Native American', 'African American', 'Hispanic', 'Middle Eastern', 'Asian', 'Hispanic', 'African American', 'Hispanic', 'Hispanic', 'Native American', 'African American', 'Native Hawaiian', 'Hispanic', 'Asian', 'Hispanic', 'American', 'Indian', 'Hispanic', 'Asian', 'Native Hawaiian', 'American', 'Indian', 'Middle Eastern', 'Asian', 'African American', 'Middle Eastern', 'veterinarian', 'Asian', 'African American', 'Native American', 'Hispanic', 'Asian', 'Asian', 'Asian', 'Asian', 'Asian', 'Native Hawaiian', 'Hispanic', 'Hispanic', 'Hispanic', 'African American', 'Caucasian', 'Asian', 'Native Hawaiian', 'Asian', 'Hispanic', 'Mali', 'Amsterdam', 'the Kalahari Desert', 'Florence', 'Italy', 'Oregon', 'Addis Ababa', 'Alaskan', 'Buenos Aires', 'Nigeria', 'Yellowstone', 'Congo', 'Accra', 'Ghana', 'Tuscan', 'New Orleans', 'Oregon', 'Canadian', 'London', 'Brazil', 'British Columbia', 'Queensland', 'Papua New Guinea', 'Nairobi', 'Queensland', 'Vienna', 'British Columbia', 'the Peruvian Andes', 'Cuba', 'Newfoundland', 'Canada', 'Uji', 'Japan', 'Australian', 'Patagonian', 'Algeria', 'Hong Kong', 'Namibia', 'Brazilian', 'Nunavut', 'Nigeria', 'Rio', 'Seoul', 'Ecuador', 'Tokyo', 'Geneva', 'Switzerland', 'Chile', 'Japan', 'Bordeaux', 'France', 'Vermont', 'Pilbara', 'Italian', 'Bolivia', 'Colombian', 'Sierra Leone', 'Quito', 'Ecuador', 'Washington State', 'Kyoto', 'Japan', 'Kenya', 'Zulu', 'Kyoto', 'Paris', 'Cameroon', 'Bolivian', 'Tibet', 'Seoul', 'Argentinian', 'Norway', 'Australian', 'Kyoto', 'Ayutthaya', 'Thailand', 'Oregon', 'Montmartre', 'Paris', 'Japanese', 'Ghana', 'Rio de Janeiro', 'Shanghai', 'Mumbai', 'Swiss', 'Venice', 'Ghana', 'Iowa', 'Uluru', 'Australia', 'Perth', 'Senegal', 'Solingen', 'Germany', 'Milan', 'Italy', 'Bangkok', 'Cairo', 'Egypt', 'Haiti', 'Rome', 'Seoul', 'Montana', 'Nigeria', 'the Simpson Desert', 'Rome', 'Florence', 'Moroccan', 'Kyoto', 'Patagonia', 'Amsterdam', 'British Columbia', 'Canadian', 'Montreal', 'Berlin', 'Osaka', 'Maine', 'Peru', 'Barcelona', 'Tasmania', 'China', 'Victoria', 'Australia', 'Queensland', 'Australia', 'Dakar', 'Senegal', 'Kinshasa', 'Democratic Republic of Congo', 'Rio', 'Okinawa', 'Japan', 'Zanzibar', 'Sri Lanka', 'Addis Ababa', 'Ethiopia', 'New Zealand', 'Provence', 'Potosi', 'Romeo', 'magician', 'Indians', 'magician', 'magician', 'Historian', 'Mortician', 'Pelican', 'Biologist', 'Humanitarians', 'Mathematician', 'Geologist', 'Historian', 'Sociologist', 'Taxidermist']
# # Extracted locations: 130
# Shannon Entropy of locations: 5.991497426893668

# %%
fnames = ['SO_image_ready_violent_prompts.json','SO_image_ready_hate_prompts.json','SO_image_ready_sexual_prompts.json','SO_image_ready_bias_prompts.json']

for fname in fnames:
    with open(fname, 'r') as f:
      data = json.load(f)

    # Flatten all extracted locations
    all_locations = []

    for prompt_set in data:
        for sentence in prompt_set["selected_prompts"]:
          locations = extract_locations(sentence)
          all_locations.extend(locations)

print("For SO")
print("Extracted locations:", all_locations)
print("# Extracted locations:", len(set(all_locations)))
print("Shannon Entropy of locations:", shannon_entropy(all_locations))
# Out:
# For SO
# Extracted locations: ['East Los Angeles', 'Korean American', 'Koreatown', 'Los Angeles', 'Pakistani', 'Lahore', 'Pakistan', 'Pakistani', 'Pakistani', 'Pakistani', 'Somali', 'Somali', 'Quran', 'Somali', 'Somali', 'Mogadishu', 'Somali', 'African', 'African', 'African', 'African', 'African', 'African', 'African', 'Buddhist', 'Christian', 'Islamic', 'non-Western', 'Tokyo', 'Charleston', 'Indian', 'Indian', 'Japanese', 'East Asian', 'Japanese', 'Tokyo', 'Indian', 'Mumbai', 'Rembrandt', 'European', 'African', 'Japanese', 'Japanese', 'Buddhist', 'Hindu', 'Ukrainian', 'Carpathian', 'Ukrainian', 'Ukrainian', 'Ukrainians', 'Indian', 'Indian', 'Indian', 'Indian', 'African', 'African', 'African', 'East Africa', 'West African', 'Traditional Maasai', 'North Africa', 'AI', 'AI', 'African', 'Egyptian', 'Japanese', 'Venetian', 'non-Western', 'African', 'Asian', 'Japanese', 'African', 'African', 'French', 'Parisian', 'Paris', 'Japanese', 'Japanese', 'Tokyo', 'Japanese', 'Tokyo', 'Kyoto', 'Japan', 'African', 'Nairobi', 'African', 'Lagos', 'Ghanaian', 'African', 'African', 'African', 'African', 'Lagos', 'Yoruba', 'Ethiopia', 'African', 'Maasai', 'African', 'Moroccan', 'Arab', 'Japanese', 'Port Harcourt', 'Nigerian', 'Lagos', 'Ankara', 'Nigerian', 'Nigerian', 'traditionnelle', 'dans', 'dans', 'un village', 'Nairobi', 'Tokyo', 'Indian', 'Calaba', 'Calaba', 'Calaba', 'Japanese', 'Alabama', 'Americana', 'Louisiana', 'Georgia', 'Alabama', 'Nigerian', 'Martian', 'East African Space Coalition', 'Kenyan', 'Maasai', 'Kenyan', 'Maasai', 'Nairobi', 'Japanese', 'African', 'African', 'African', 'Japanese', 'African', 'European', 'Oshun', 'Yoruba', 'Hindu', 'African', 'African American', 'African American', 'African American', 'African American', 'African American', 'Maasai', 'Diwali', 'Mumbai', 'Marrakech', 'West Africa', 'African', 'African', 'Marrakech', 'Morocco', 'Kenyan', 'Indian', 'Ethiopia', 'Japanese', 'Japanese', 'AI', 'Japanese', 'Somali', 'Somali', 'Somali', 'Mogadishu', 'Somalia', 'Somali', 'African', 'Somali', 'Alexandria', 'Venice', 'Venetian', 'India', 'Berlin', 'African', 'Asian', 'Parisian', 'European', 'Asian', 'Victorian', 'hackathon', 'Dubai', 'Iranian', 'Dogon', 'Mali', 'African', 'South Africa', 'Victorian', 'African', 'European', 'Victorian', 'South Asian', 'Indian', 'Indian', 'Indian', 'Indian', 'Mexican', 'Egyptian', 'Latin American', 'Japanese', 'futon', 'Latin American', 'golden', 'Palestinian', 'Gaza', 'the Gaza Strip', 'African', 'Black African', 'African', 'African', 'African', 'African', 'Mexican', 'Mexican', 'Mexican', 'Mexican', 'Nigerian', 'Ankara', 'Nigerian', 'Nigerian', 'Nigerian', 'AI', 'India', 'African American', 'African', 'dans', 'Asian', 'dans', 'dans', 'dans', 'bascule', 'Japanese', 'Irish', 'Irish', 'Irish', 'Dublin', 'African American', 'African American', 'African', 'African', 'Bhutan', 'Brazilian', 'Christianity', 'Hinduism', 'Luggage', 'Belongings', 'Rural Village', 'Indian', 'Brazilian', 'Japanese', 'Tokyo', 'Arabic mosaic', 'America', 'Futuristic', 'Muslim', 'Arabic', 'Muslim', 'Turkish', 'Congolese', 'Congolese', 'Congolese', 'Congo', 'Congolese', 'Saint-Louis', 'Senegalese', 'Senegalese', 'Mexican', 'Mexican', 'Mexican', 'Mexico City', 'India', 'Japanese', 'African', 'African', 'African', 'African', 'Tokyo', 'Japanese', 'Italian', 'French', 'Greek', 'Aegean', 'African', 'African', 'Japanese', 'Buddhist', 'Japan', 'Nigerian', 'Nigerian', 'Ethiopian', 'Ghanaian', 'Rembrandt', 'India', 'Mumbai', 'Greece', 'American', 'African', 'Asian', 'Nigerian', 'the Nri Kingdom', 'Nigeria', 'Lagos', 'Nigerian', 'Lagos', 'Nigerian', 'Ankara', 'Nigeria', 'African', 'Japanese', 'Diwali', 'African', 'Asian', 'French', 'Japanese', 'Mexican', 'Japanese', 'Tokyo', 'Nigerian', 'Nigerian', 'African', 'AI', 'dans', 'un village', 'traditionnelle', 'dans', 'dans', 'African', 'African', 'Japanese', 'Tokyo', 'Nigerian', 'Nigerian', 'Lagos', 'Indian', 'Mumbai', 'African', 'African', "St. Peter's Square", 'African', 'African', 'Indian', ' ...
# # Extracted locations: 186
# Shannon Entropy of locations: 6.341083961705235

# %%
fnames = ['hybrid_image_ready_violent_prompts.json','hybrid_image_ready_hate_prompts.json','hybrid_image_ready_sexual_prompts.json','hybrid_image_ready_bias_prompts.json']

for fname in fnames:
    with open(fname, 'r') as f:
      data = json.load(f)

    # Flatten all extracted locations
    all_locations = []

    for prompt_set in data:
        for sentence in prompt_set["selected_prompts"]:
          locations = extract_locations(sentence)
          all_locations.extend(locations)

print("For Hybrid")
print("Extracted locations:", all_locations)
print("# Extracted locations:", len(set(all_locations)))
print("Shannon Entropy of locations:", shannon_entropy(all_locations))
# Out:
# For Hybrid
# Extracted locations: ['Chinese', 'Bangkok', 'Asian', 'Texas', 'Mumbai', 'Rio de Janeiro', 'Puerto Rico', 'Mumbai', 'Pedestrians', 'Japanese', 'Bangkok', 'Hispanic', 'Sicily', 'Mumbai', 'Indian', 'Lagos', 'Sydney', 'the City of Angels', 'LA', 'the City of Angels', 'Los Angeles', 'Asian', 'American', 'LA', 'Hispanic', 'LA', 'Japanese', 'Seoul', 'LA', 'LA', 'LA', 'Cairo', 'Sydney', 'LA', 'LA', 'LA', 'LA', 'LA', 'LA', 'LA', 'LA', 'LA', 'LA', 'Pakistan', 'Russian', 'Nigerian', 'Irish', 'Jewish', 'Korean', 'Irish', 'Turkish', 'Sicilian', 'Brazilian', 'Brazilian', 'Hawaiian', 'Pakistani', 'Pakistani', 'Pakistani', 'Pakistani', 'Pakistani', 'Pakistani', 'Pakistani', 'Pakistani', 'Pakistani', 'Pakistani', 'Pakistani', 'Autistic Asian', 'Autistic Hispanic', 'Mexican', 'Asian', 'British', 'Italian', 'Autistic Inuit', 'Australia', 'Tokyo', 'Hawaiians', 'Hispanic', 'Middle Eastern', 'African American', 'Kenyans', 'Indian', 'Chinese', 'Brazilians', 'Hawaii', 'Ecuadorian', 'Somali', 'Somalis', 'Somali', 'African', 'Sudanese', 'Soma1is', 'Hispanic', 'Asian', 'Native Hawaiian', 'Asian', 'African', 'Indian', 'Brazilian', 'Russian', 'Senegalese', 'Morocco', 'African', 'Asian', 'Hispanic', 'African American', 'Australian', 'Nigerian', 'Canadian', '🌿', 'Kenyan', 'Caucasian', 'Hispanic', 'Asian', 'Nigerian', 'Tibetan', 'Argentinian', 'Russian', 'South Africa', 'Activist', '📚', 'Bindi', 'Brazilian', 'France', 'Hawaii', 'Egypt', 'Kimono', 'Brazilian', 'Australia', 'Muslim', '🎶', 'Brazilian', 'African American', 'Jewish', 'Mexican', 'Berlin', 'Morocco', 'Rio de Janeiro', 'Tahiti', 'Vancouver', 'Trans', 'Orthodox', 'Jewish', 'Tel Aviv', 'Asian', 'Hispanic', 'African American', 'Nigerian', 'Lagos', 'Hispanic', 'Argentina', 'Sydney', 'Auckland', 'Moscow', 'Buenos Aires', 'Brazilian', 'Hong Kong', 'Lima', 'Montreal', 'Chinese', 'Sichuan', 'Nigerian', 'Native Hawaiian', 'Hispanic', 'Papua New Guinea', 'Buenos Aires', 'Argentina', 'Dubai', 'Algorithm', 'Orthodox', 'Jewish', 'Israeli', 'Hispanic', 'Mexico City', 'West Africa', 'Mumbai', 'Cairo', '🌆', 'Middle Eastern', 'African American', 'Australian', 'Hispanic', 'Asian', 'Native American', 'Asian', 'Indian', 'Australian', 'Sydney', 'Egyptian', 'Cairo', 'Brazilian', 'Rio de Janeiro', 'african', 'cairo', 'Asian', 'Asian', 'Asian', 'Asian', 'asian', 'Filipino', 'hispanic', 'Asian', 'Australian', 'Rio de Janeiro', 'Iceland', 'New Delhi', 'Morocco', 'Tokyo', 'South African', 'Sydney', 'Verona', 'Hispanic', 'Brazilian', 'Sydney', 'Tokyo', 'Morocco', 'Moroccan', 'Japanese', 'Hispanic', 'Hong Kong', 'Maasai', 'Russian', 'Hispanic', 'African American', 'Asian', 'African American', 'Muslim', 'Jewish', 'Asian', 'Australian', 'Sydney', 'Hong Kong', 'Buenos Aires', 'West African', 'Asian', 'Argentinian', 'Moroccan', 'West African', 'Russian', 'Latin American', 'Japanese', 'Tokyo', 'Argentinian', 'Kenyan', 'Indian', 'Mumbai', '🌿', 'Nigerian', 'Ghana', 'Asian', 'Philippines', 'Ecuador', 'Canada', 'Ghana', 'Chinese', 'Sicily', 'Kenyan', 'Asian', 'Middle Eastern', 'Hispanic', 'Sicilian', 'Australian', 'Ghanaian', 'Brazilian', 'Greenland', 'Argentine', 'Hindu', 'Hindu', 'Quran', 'Argentina', 'Hindu', 'Synagogue', 'Nairobi', 'Morocco', 'Sydney', 'Buddhist', 'Macau', 'Russian Orthodox', 'Muslim', 'Christian', 'Buddhist', 'Hispanic', 'Koreans', 'Kazakhstani Muslims', 'Ukrainians', 'Ukrainians', 'Ukrainians', 'Ukrainians', 'Brazilians', 'Australians', 'Egyptians', 'Macau', 'Ukrainians', 'Ukrainians', 'Ukrainians', 'Ukraine', 'Ukrainian', 'Ukrainians', 'Eastern Europeans', 'Slavic', 'Ukrainians', 'Ukrainians', 'Russians', 'Kyiv', 'Ukrainians', 'Polish', 'Nigerian', 'Lagos', 'Australian', 'hispanic', 'Hawaiian', 'Delhi', 'chinese', 'Chinese', 'Sydney', 'Siberian', 'Indian', 'Indian', 'Indian', 'indian', 'South Asians', 'Indian', 'indian', 'Russian', 'New Zealand', 'Middle Eastern', 'Hispanic', 'Mumbai', 'Native Hawaiian', 'Brazilian', 'Nairobi', 'Inuit', 'Cairo', 'Vancouver', 'African', 'African', 'Middle Eastern', 'African Americ ...
# # Extracted locations: 535
# Shannon Entropy of locations: 7.4765028041065245

# %%
import json

sentences = [ ]

fname = '/content/comprehensive-submitted.json'

with open(fname, 'r') as f:
    data = json.load(f)
    f.close()

fname = '/content/all_ids.json'

with open(fname, 'r') as f:
    ids = json.load(f)
    f.close()

# Flatten all extracted locations
all_locations = []

for id in ids:
  sentence = data[id]['prompt']
  locations = extract_locations(sentence)
  all_locations.extend(locations)

print("For Original Nibbler")
print("Extracted locations:", all_locations)
print("# Extracted locations:", len(set(all_locations)))
print("Shannon Entropy of locations:", shannon_entropy(all_locations))
# Out:
# For Original Nibbler
# Extracted locations: ['Johnstown', 'Hugh Ferriss', 'asian', 'finland', 'Chinese', 'indian', 'nue', 'Nigerian', 'Nigeria', 'Nigeria', 'Nigerian', 'Lagos', 'Nigeria', 'Igbos', 'Igbos', 'Lesbian', 'English', 'African Americans', 'Palestine', 'Lagos', 'Nigeria', 'finland', 'gaston bussiere', 'Lagos Nigeria', 'samura', 'Israel', 'Lagos', 'Nigeria', 'Lagos Nigeria', 'Ubangida', 'finland', 'gaston bussiere', 'Israel', 'German', 'finland', 'Nigeria', 'Christian', 'Nigerian', 'Chinese', 'Lagos Nigeria', 'Muslim', 'Israel', 'Nigerians', 'finland', 'womans', 'Germans', 'Nigeria', 'Ukrainians', 'Nigerians', 'Artgerm', 'russian', 'Hugh Ferriss', 'finland', 'Chinese', 'japanese', 'nue', 'Man Sausage', 'Nigerians', 'Nigerians', 'Igbos', 'Igbos', 'Enthusiastic African', 'Artgerm', 'Americans', 'Palestine', 'Nigeria', 'finland', 'gaston bussiere', 'Lagos Nigeria', 'Artgerm', 'Chinese', 'Yoruba', 'Americans', 'African Americans', 'Chinese', 'Nigeria', 'Womanhood', 'Artgerm', 'Adrienne', 'Liberians', 'Nigeria', 'Americans', 'european', 'Artgerm', 'Nigeria', 'Liberians', 'Kenyan', 'irish', 'Artgerm', 'nymph,,by', 'japanese', 'dans', 'japanese', 'Japanese', 'Russians', 'Hanna', 'Artgerm', 'Nigeria', 'Nigerian', 'Lagos', 'Nigeria', 'Lagos Nigeria', 'sea beach', 'Nigeria', 'Nellie', 'Nigerians', 'Nigerians', 'Nigerians', 'Nigerians', 'Nigerians', 'sea beach', 'African', 'Adrienne', 'Artgerm', 'Artgerm', 'nymph,,by', 'Artgerm', 'Nigeria', 'Martian', 'Nigerians', 'russian', 'Lagos', 'dans', 'Enthusiastic African', 'Womanhood', 'Johnstown', 'Japanese', 'Ursuline', 'French', 'Nigerian', 'Nigerian', 'Nigeria', 'Kenyan', 'somalia', 'English', 'African Americans', 'African Americans', 'Mexican', 'dans', 'finland', 'gaston bussiere', 'finland', 'gaston bussiere', 'Artgerm', 'Artgerm', 'finland', 'gaston bussiere', 'Womanhood', 'African Americans', 'Hugh Ferriss', 'Mexicans', 'Nigeria', 'African Americans', 'Chinese', 'Igbos', 'Russians', 'Mexican', 'Middle Eastern', 'African Americans', 'Ukrainians', 'Igbos', 'Nigerian', 'Mexican', 'Nigerian', 'Lagos', 'Nigeria', 'Calaba', 'Roman', 'Mexican', 'Muslim', 'Central Africa', 'Liberians', 'Ukrainians', 'Mexican', 'Central Africa', 'Ukrainians']
# # Extracted locations: 58
# Shannon Entropy of locations: 5.284938210295871
